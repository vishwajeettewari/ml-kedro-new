# %%
df = catalog.load('hr_data').head()
# Out:
# 2021-05-12 00:13:47,277 - kedro.io.data_catalog - INFO - Loading data from `hr_data` (CSVDataSet)...

# %%
df
# Out:
#    Age Attrition  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0   41       Yes       1102                 1          2              1
# 1   49        No        279                 8          1              1
# 2   37       Yes       1373                 2          2              1
# 3   33        No       1392                 3          4              1
# 4   27        No        591                 2          1              1
#
#    EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  ...  \
# 0               1                        2          94               3  ...
# 1               2                        3          61               2  ...
# 2               4                        4          92               2  ...
# 3               5                        4          56               3  ...
# 4               7                        1          40               3  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
x_train = catalog.load('X_train').head()
# Out:
# 2021-05-12 00:15:11,914 - kedro.io.data_catalog - INFO - Loading data from `X_train` (CSVDataSet)...

# %%
x_train
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   29        896                18          1              1             315
# 1   53       1223                 7          2              1            1201
# 2   32        371                19          3              1            1739
# 3   33       1296                 6          3              1             692
# 4   43        982                12          3              1             520
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  ...  \
# 0                        3          86               2         1  ...
# 1                        4          50               3         5  ...
# 2                        4          80               1         3  ...
# 3                        3          30               3         2  ...
# 4                        1          59               2         4  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
session.run()
# Out:
# 2021-05-12 00:15:25,829 - root - INFO - ** Kedro project hr-attr
# 2021-05-12 00:15:26,566 - kedro.io.data_catalog - INFO - Loading data from `hr_data` (CSVDataSet)...
# 2021-05-12 00:15:26,573 - kedro.pipeline.node - INFO - Running node: make_plot: make_plot([hr_data]) -> [m_plot]
# 2021-05-12 00:15:26,621 - kedro.io.data_catalog - INFO - Saving data to `m_plot` (MatplotlibWriter)...
# 2021-05-12 00:15:26,740 - kedro.runner.sequential_runner - INFO - Completed 1 out of 4 tasks
# 2021-05-12 00:15:26,741 - kedro.io.data_catalog - INFO - Loading data from `hr_data` (CSVDataSet)...
# 2021-05-12 00:15:26,747 - kedro.io.data_catalog - INFO - Loading data from `parameters` (MemoryDataSet)...
# 2021-05-12 00:15:26,748 - kedro.pipeline.node - INFO - Running node: split_data_node: split_data([hr_data,parameters]) -> [X_test,X_train,y_test,y_train]
# 2021-05-12 00:15:26,750 - kedro.io.data_catalog - INFO - Saving data to `X_train` (CSVDataSet)...
# ...

# %%
session.run()[dp]
# Out:
# 2021-05-12 00:17:34,632 - root - INFO - ** Kedro project hr-attr
# 2021-05-12 00:17:34,644 - kedro.io.data_catalog - INFO - Loading data from `hr_data` (CSVDataSet)...
# 2021-05-12 00:17:34,653 - kedro.pipeline.node - INFO - Running node: make_plot: make_plot([hr_data]) -> [m_plot]
# 2021-05-12 00:17:34,696 - kedro.io.data_catalog - INFO - Saving data to `m_plot` (MatplotlibWriter)...
# 2021-05-12 00:17:34,792 - kedro.runner.sequential_runner - INFO - Completed 1 out of 4 tasks
# 2021-05-12 00:17:34,793 - kedro.io.data_catalog - INFO - Loading data from `hr_data` (CSVDataSet)...
# 2021-05-12 00:17:34,799 - kedro.io.data_catalog - INFO - Loading data from `parameters` (MemoryDataSet)...
# 2021-05-12 00:17:34,800 - kedro.pipeline.node - INFO - Running node: split_data_node: split_data([hr_data,parameters]) -> [X_test,X_train,y_test,y_train]
# 2021-05-12 00:17:34,802 - kedro.io.data_catalog - INFO - Saving data to `X_train` (CSVDataSet)...
# ...

# %%
catalog.print('m_plot')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-fa645a2a288a> in <module>
# ----> 1 catalog.print('m_plot')
#
# AttributeError: 'DataCatalog' object has no attribute 'print'
